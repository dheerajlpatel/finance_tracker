# %%
# importing required classes 
from pypdf import PdfReader
reader = PdfReader(r'C:\Users\pc\Desktop\Dheeraj\Finance analysis\pdf\yearly statment\0968XXXXXX7192_41589d1c_01Jan2023_TO_01Dec2023_205431694.pdf')

# %%
# creating a page object 
page = reader.pages[1] 
  
# extracting text from page 
print(page.extract_text())
# Out:
# Mr.  Dheeraj Patel
#
# Statement From : 01/01/23    TO : 01/12/23
# Account Branch
# A/C Open Date
# Limit
# City
# Phone No.
# Cust ID
# Account Status
# Account number
# State
# RTGS/NEFT IFSC
# JOINT HOLDERS:
#
# Address
# Email
# Currency
# Pr.Code
# Br.Code
# VIRTUAL PREFERRED
# : Gachibowli
# : Plot No.79, Ground And First Floor,
#   Diamond Park, Vinayak Nagar,
#   Gachibowli,
# : Hyderabad 500032
# : Telangana
# : 18002026161
# : HDFC0000968
# : dheerajlpatel@gmail.com
# : 0.00
# : INR
# : 43691790
# : 161
# :968
# : 09681610047192
# : 16/06/2012
# : Account Open Regular
# Not Applicable
# Not Applicable
# Nomination     : Registered
# 500240029
# MICR :
# Ward No 01 Makan No 115/2
# Vaidya Hira Buwa Gali
# Mahajanapeth Burhanpur
# Burhanpur
# Madhya Pradesh
# India
# 450331
# Expected AMB
# : 0.00
# 02/01/2023UPI-INDIAN RAILWAYS TICK-PAYTM-64670120@
# PAYTM-PYTM0123456-300275055344-PAYMENT F
# ROM PHONE300275055344 02/01/2023 10.00 0.00 60,922.93
# ...
